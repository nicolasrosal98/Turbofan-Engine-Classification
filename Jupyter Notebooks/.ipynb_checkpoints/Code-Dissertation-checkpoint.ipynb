# %% [markdown]
# # Dissertation II - Code

# %% [markdown]
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Import Libraries

# %%
# Avoid Future Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
## Data managing
import pandas as pd
import numpy as np
import math
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from ydata_synthetic.synthesizers.regular import WGAN_GP 

## Data visualisations
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import tree


## Modelling 

# sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier

# xgboost
from xgboost.sklearn import XGBClassifier

# keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


## Scoring
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

## Tuning
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Helper Functions

# %%
#Adapted from: Kucherevskiy, I. RUL Prediction [Internet]. Kaggle; 2020 [cited 26 March 2021].
#Available from: <https://www.kaggle.com/kucherevskiy/rul-prediction>

def prepare_data(data):
    df = data.copy()
    tempMax = df.groupby('unit_number')['time_in_cycles'].max().reset_index()
    tempMax = pd.DataFrame(tempMax)
    tempMax.columns = ['unit_number','max']
    df = df.merge(tempMax, on=['unit_number'], how='left')
    df['label'] = np.where(df['max'] - df['time_in_cycles'] <= 15, 1, 0 )
    df.drop(columns=['max'],inplace = True)
    
    return df

# %%
# Adapted from: Singh, D. Cleaning up Data from Outliers [Internet]. Plural Sight; October 2019 [cited 27 March 2021].
# Available from: <https://www.pluralsight.com/guides/cleaning-up-data-from-outliers>

def find_outliers(dataset):
    
    outliers = {}
    
    for i in list(dataset.loc[:, dataset.dtypes != 'category']):
        Q1 = dataset[i].quantile(0.25)
        Q3 = dataset[i].quantile(0.75)
        IQR = Q3 - Q1
        num_outliers = ((dataset[i] < (Q1 - 1.5 * IQR)) | (dataset[i] > (Q3 + 1.5 * IQR)))
        outliers[i] = num_outliers
        
    return outliers

# %%
def plot_box(dataset):
    
    outliers = find_outliers(dataset)
    
    fig = plt.figure(figsize=(20,20))
    fig.subplots_adjust(wspace=0.5, hspace=0.7)
    for i, column in enumerate(outliers.keys()):
        ax = fig.add_subplot(4, 3, i + 1)
        g = sns.boxplot(dataset[column])
        ax.set_title('Box plot of {}. Outliers: {}'.format(column, outliers[column].sum()))

# %%
def plot_distribution(dataset, normal=False):
    
    fig = plt.figure(figsize=(20,15))
    fig.subplots_adjust(wspace=0.5, hspace=0.7)
    for i, column in enumerate(dataset.columns):
        ax = fig.add_subplot(4, 4, i + 1)
        ax.set_title(column)
        g = sns.distplot(dataset[column])
        plt.xticks(rotation=25)
        if normal: 
            ax.set_xlim(-4,4)

# %%
# Plot class distribution
def class_distribution(data, name):
    plt.figure(figsize=(8, 6))
    plt.bar(data['label'].unique(), data['label'].value_counts(), color=['green', 'red'])
    plt.title('Distribution of Classes: {}'.format(name))
    plt.xlabel('Class')
    plt.ylabel('Count')
    plt.xticks([0,1], ['Healthy (0)', 'Risk of Failure (1)'])
    plt.ylim(0, 30000)
    for i, value in enumerate(data['label'].value_counts()):
        plt.text(x=i , y =value+1 , s=f"{value}" , fontdict=dict(fontsize=15))
    plt.show()

# %% [markdown]
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Importing Data and Initial Cleaning

# %%
# Column Names
columns = ['unit_number','time_in_cycles','Altitude','Mach','TRA','T2','T24','T30','T50','P2','P15','P30','Nf',
           'Nc','epr','Ps30','phi','NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32' ]

# %%
# Train
df = pd.read_csv('/Users/nicolasrosal/Desktop/Dissertation2/CMAPSSData/train_FD003.txt',
                 sep=" ",
                 header=None)

# %% [markdown]
# - Dataframe1:

# %%
# Dropping empty columns
df.drop(columns=[26,27], inplace=True)

# %%
#Renaming Columns
df.columns = columns

# %% [markdown]
# ###### Creating a dataframe for Exploratory Data Analysis and Modelling

# %%
TTF_data = prepare_data(df)

# %%
TTF_data.to_csv('/Users/nicolasrosal/Desktop/Dissertation2/TTF_data.csv')

# %% [markdown]
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# - Shape:

# %%
TTF_data.shape
# Out:
# (24720, 27)

# %% [markdown]
# - Data Types:

# %%
TTF_data['label'] = TTF_data['label'].astype('category')

# %%
TTF_data.dtypes
# Out:
# unit_number          int64
# time_in_cycles       int64
# Altitude           float64
# Mach               float64
# TRA                float64
# T2                 float64
# T24                float64
# T30                float64
# T50                float64
# P2                 float64
# P15                float64
# P30                float64
# Nf                 float64
# Nc                 float64
# epr                float64
# Ps30               float64
# phi                float64
# NRf                float64
# NRc                float64
# BPR                float64
# farB               float64
# htBleed              int64
# Nf_dmd               int64
# PCNfR_dmd          float64
# W31                float64
# W32                float64
# label             category
# dtype: object

# %% [markdown]
# - Missing Values:

# %%
print('Number of missing values:', TTF_data.isna().sum().sum())
# Out:
# Number of missing values: 0

# %% [markdown]
# - Descriptive Statistics:

# %%
TTF_data.describe()
# Out:
#         unit_number  time_in_cycles      Altitude          Mach      TRA  \
# count  24720.000000    24720.000000  24720.000000  24720.000000  24720.0
# mean      48.631877      139.077063     -0.000024      0.000005    100.0
# std       29.348985       98.846675      0.002194      0.000294      0.0
# min        1.000000        1.000000     -0.008600     -0.000600    100.0
# 25%       23.000000       62.000000     -0.001500     -0.000200    100.0
# 50%       47.000000      124.000000      0.000000     -0.000000    100.0
# 75%       74.000000      191.000000      0.001500      0.000300    100.0
# max      100.000000      525.000000      0.008600      0.000700    100.0
#
#                  T2           T24           T30           T50            P2  \
# count  2.472000e+04  24720.000000  24720.000000  24720.000000  2.472000e+04
# mean   5.186700e+02    642.457858   1588.079175   1404.471212  1.462000e+01
# std    6.684921e-11      0.523031      6.810418      9.773178  3.602525e-12
# min    5.186700e+02    640.840000   1564.300000   1377.060000  1.462000e+01
# 25%    5.186700e+02    642.080000   1583.280000   1397.187500  1.462000e+01
# 50%    5.186700e+02    642.400000   1587.520000   1402.910000  1.462000e+01
# 75%    5.186700e+02    642.790000   1592.412500   1410.600000  1.462000e+01
# max    5.186700e+02    645.110000   1615.390000   1441.160000  1.462000e+01
#
#        ...           phi           NRf           NRc           BPR  \
# count  ...  24720.000000  24720.000000  24720.000000  24720.000000
# mean   ...    523.050873   2388.071643   8144.202916      8.396176
# std    ...      3.255314      0.158121     16.504118      0.060512
# min    ...    517.770000   2386.930000   8099.680000      8.156300
# 25%    ...    521.150000   2388.010000   8134.510000      8.360600
# 50%    ...    521.980000   2388.070000   8141.200000      8.398300
# 75%    ...    523.840000   2388.140000   8149.230000      8.437000
# max    ...    537.400000   2388.610000   8290.550000      8.570500
#
#                farB       htBleed   Nf_dmd  PCNfR_dmd           W31  \
# count  2.472000e+04  24720.000000  24720.0    24720.0  24720.000000
# mean   3.000000e-02    392.566545   2388.0      100.0     38.988552
# std    1.750371e-14      1.761459      0.0        0.0      0.248865
# min    3.000000e-02    388.000000   2388.0      100.0     38.170000
# 25%    3.000000e-02    391.000000   2388.0      100.0     38.830000
# 50%    3.000000e-02    392.000000   2388.0      100.0     38.990000
# 75%    3.000000e-02    394.000000   2388.0      100.0     39.140000
# max    3.000000e-02    399.000000   2388.0      100.0     39.850000
#
#                 W32
# count  24720.000000
# mean      23.393024
# std        0.149234
# min       22.872600
# 25%       23.296200
# 50%       23.391600
# 75%       23.483300
# max       23.950500
#
# [8 rows x 26 columns]

# %%
# Drop columns with constant values (std < 0.0001), time_in_cycles (not a time series analysis), and unit_number
TTF_data.drop(columns=['unit_number','time_in_cycles', 'TRA','T2', 'P2', 'farB', 'Nf_dmd', 'PCNfR_dmd'],
              inplace=True)

# %%
TTF_data[['NRf', 'BPR']].describe()
# Out:
#                 NRf           BPR
# count  24720.000000  24720.000000
# mean    2388.071643      8.396176
# std        0.158121      0.060512
# min     2386.930000      8.156300
# 25%     2388.010000      8.360600
# 50%     2388.070000      8.398300
# 75%     2388.140000      8.437000
# max     2388.610000      8.570500

# %% [markdown]
# - Correlation Analysis:

# %%
#Source: https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e
plt.figure(figsize=(15, 15))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(TTF_data.corr(), dtype=np.bool))
heatmap = sns.heatmap(np.round(TTF_data.corr(), 2), mask=mask, vmin=-1, vmax=1, annot=True, cmap='RdYlGn')
heatmap.set_title('Correlation Heatmap');

# %% [markdown]
# ###### R code for additional analysis on highly correlated variables (r > 0.9)
#
# library(readxl)
#
# library(ellipse)
#
# library(RColorBrewer)
#
# df <- read.csv("/Users/nicolasrosal/Desktop/Dissertation2/TTF_data.csv")[ ,c("phi", "NRf", "NRc", "P30", "Nf", "Nc")]
#
# data=cor(df, use="complete.obs")
#
# plotcorr(data , col="lightgreen",
#          cex.lab=0.75 ,
#          type = "upper" ,
#          diag=FALSE)

# %%
from IPython.display import Image
Image("/Users/nicolasrosal/Desktop/pairplot.png")

# %%
# Drop highly correlated variables and uncorrelated variables
TTF_data.drop(columns=['Altitude', 'Mach', 'phi', 'Nf', 'Nc'], inplace=True)

# %% [markdown]
# - Outlier Analysis:

# %%
plot_box(TTF_data.drop(columns=['label']))

# %%
# Exploring outliers 1.5 times IQR below/above in NRf label 0
data = TTF_data[TTF_data['label'] == 0]
Q1 = data['NRf'].quantile(0.25)
Q3 = data['NRf'].quantile(0.75)

IQR = Q3 - Q1
num_outliers_low = data[TTF_data['NRf'] < (Q1 - 1.5 * IQR)]
num_outliers_high = data[TTF_data['NRf'] > (Q3 + 1.5 * IQR)]

print('Number of outliers 1.5 times IQR below Q1: {}'.format(num_outliers_low.shape[0]))
print('Number of outliers 1.5 times IQR above Q3: {}'.format(num_outliers_high.shape[0]))
# Out:
# Number of outliers 1.5 times IQR below Q1: 689
# Number of outliers 1.5 times IQR above Q3: 686

# %%
# Exploring outliers 1.5 times IQR above in NRc label 1
data = TTF_data[TTF_data['label'] == 1]
Q1 = data['NRc'].quantile(0.25)
Q3 = data['NRc'].quantile(0.75)

IQR = Q3 - Q1
num_outliers_high = data[TTF_data['NRc'] > (Q3 + 1.5 * IQR)]

print('Number of outliers 1.5 times IQR above Q3: {}'.format(num_outliers_high.shape[0]))
# Out:
# Number of outliers 1.5 times IQR above Q3: 16

# %%
# Exploring outliers 1.5 times IQR below in epr label 0
data = TTF_data[TTF_data['label'] == 0]
Q1 = data['epr'].quantile(0.25)
Q3 = data['epr'].quantile(0.75)

IQR = Q3 - Q1
num_outliers_low = data[TTF_data['epr'] < (Q1 - 1.5 * IQR)]

print('Number of outliers 1.5 times IQR below Q1: {}'.format(num_outliers_low.shape[0]))
# Out:
# Number of outliers 1.5 times IQR below Q1: 9

# %% [markdown]
# - Class Distribution:

# %%
class_distribution(TTF_data, 'Original Data')

# %% [markdown]
# - Variables' Distribution:

# %%
plot_distribution(TTF_data.drop(columns=['label']))

# %% [markdown]
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Feature Engineering

# %%
# Splitting the data into X (parameters) and y (label)
X = TTF_data.drop(columns=['label']).values
y = TTF_data['label'].values

# %%
# Scaling Data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Creating TFF_scaled
TTF_scaled = pd.DataFrame(X_scaled)
TTF_scaled['label'] = y
TTF_scaled.columns = ['T24', 'T30', 'T50', 'P15', 'P30', 'epr', 'Ps30', 'NRf',
                      'NRc', 'BPR', 'htBleed', 'W31', 'W32', 'label']

# %%
# Visualising distributions
plot_distribution(TTF_scaled.drop(columns=['label']), normal=True)

# %%
# Difference between NRc and NRc Scaled
datasets = [TTF_data, TTF_scaled]

plt.style.use('seaborn-whitegrid')
fig = plt.figure(figsize=(20,10))
fig.subplots_adjust(wspace=0.5, hspace=0.5)
for index, data in enumerate(datasets):
    ax = fig.add_subplot(1, 2, index + 1)
    g = sns.distplot(data['NRc'])
    plt.xticks(rotation=25)
    if index == 0: 
        ax.set_title('NRc', fontsize=20)
        ax.set_ylabel('Density', fontsize=15)
        ax.set_xlabel('NRc', fontsize=15)
    else:
        ax.set_title('NRc Scaled', fontsize=20)
        ax.set_ylabel('Density', fontsize=15)
        ax.set_xlabel('NRc Scaled', fontsize=15)
        ax.set_xlim(-4,4)

# %% [markdown]
# ### Data Imbalance

# %%
# Display class counts
class_distribution(TTF_scaled, 'Scaled Data')

# %%
# Splitting intro train and test data
X_train, X_test, y_train, y_test = train_test_split(TTF_scaled.drop(columns=['label']), 
                                                    TTF_scaled['label'], 
                                                    test_size=0.2, 
                                                    random_state=123)

# %% [markdown]
# ### No Data Imbalance

# %%
failure = TTF_scaled[TTF_scaled.label == 1]
healthy = TTF_scaled[TTF_scaled.label == 0]

# %% [markdown]
# - Upsampling:

# %%
# Upsample minority class
failure_upsampled = resample(failure,
                             n_samples=healthy.shape[0],
                             random_state=123)
 
# Combine majority class with upsampled minority class
data_upsampled = pd.concat([healthy, failure_upsampled])

# %%
# Display new class counts - upsampled data
class_distribution(data_upsampled, 'Upsampled Data')

# %%
# Splitting intro train and test data
Xbal_train, Xbal_test, ybal_train, ybal_test = train_test_split(data_upsampled.drop(columns=['label']), 
                                                                data_upsampled['label'], 
                                                                test_size=0.2, 
                                                                random_state=123)

# %% [markdown]
# - Synthetic Data:

# %% [markdown]
# Adapted from - https://github.com/ydataai/ydata-synthetic/blob/master/examples/regular/wgan_example.py

# %%
# Define model, data columns and label column
model = WGAN_GP
data_cols = list(failure.columns[failure.columns != 'label'])
label_cols = ['label']

# %%
#Defining training data for GAN
train_data = failure.copy().reset_index(drop=True)

# %%
#Define the GAN and training parameters
noise_dim = 0
dim = 64
batch_size = 64

log_step = 100
epochs = 500
learning_rate = 1e-3
beta_1 = 0.5
beta_2 = 0.5
models_dir = './cache'

gan_args = [batch_size, learning_rate, beta_1, beta_2, noise_dim, train_data[data_cols].shape[1], dim]
train_args = ['', epochs, log_step]

# %%
#Training the WGAN_GP model
synthesizer = model(gan_args, n_critic=1)
synthesizer.train(train_data[data_cols], train_args)
# Out:
#   3%|▎         | 16/500 [00:01<09:57,  1.23s/it]
# Iteration: 0 | disc_loss: 1.4364702701568604 | gen_loss: -0.005647141486406326
# Iteration: 1 | disc_loss: 0.0235209409147501 | gen_loss: -0.004482910968363285
# Iteration: 2 | disc_loss: -0.13448719680309296 | gen_loss: -0.0035962844267487526
# Iteration: 3 | disc_loss: -0.43378615379333496 | gen_loss: -0.002562398323789239
# Iteration: 4 | disc_loss: -0.3633763790130615 | gen_loss: -0.0021084523759782314
# Iteration: 5 | disc_loss: -0.5967726111412048 | gen_loss: -0.0008507720194756985
# Iteration: 6 | disc_loss: -0.6232218146324158 | gen_loss: -0.0010303161107003689
# Iteration: 7 | disc_loss: -0.7353940606117249 | gen_loss: -0.00011069467291235924
# Iteration: 8 | disc_loss: -0.7832695841789246 | gen_loss: 0.0015204045921564102
# Iteration: 9 | disc_loss: -0.7972801327705383 | gen_loss: 0.002410425804555416
# Iteration: 10 | disc_loss: -0.6858487725257874 | gen_loss: 0.004592704586684704
# Iteration: 11 | disc_loss: -0.7636187672615051 | gen_loss: 0.0055372160859405994
# Iteration: 12 | disc_loss: -0.8141704201698303 | gen_loss: 0.005634770728647709
# Iteration: 13 | disc_loss: -0.732668936252594 | gen_loss: 0.008579311892390251
# Iteration: 14 | disc_loss: -0.8317931294441223 | gen_loss: 0.009697826579213142
# Iteration: 15 | disc_loss: -0.8488531112670898 | gen_loss: 0.009601329453289509
# Iteration: 16 | disc_loss: -0.8167212009429932 | gen_loss: 0.012449256144464016
# Iteration: 17 | disc_loss: -0.850487470626831 | gen_loss: 0.013644790276885033
# Iteration: 468 | disc_loss: -0.8352364897727966 | gen_loss: -0.047142527997493744
# Iteration: 469 | disc_loss: -0.8426255583763123 | gen_loss: -0.04946514219045639
# Iteration: 470 | disc_loss: -0.8428394198417664 | gen_loss: -0.04548998177051544
# Iteration: 471 | disc_loss: -0.8426461219787598 | gen_loss: -0.05710555613040924
# Iteration: 472 | disc_loss: -0.8169925212860107 | gen_loss: -0.04381904751062393
# Iteration: 473 | disc_loss: -0.8309904932975769 | gen_loss: -0.047872018069028854
# Iteration: 474 | disc_loss: -0.8495619297027588 | gen_loss: -0.0587678961455822
# Iteration: 475 | disc_loss: -0.8062556982040405 | gen_loss: -0.0448303148150444
# Iteration: 476 | disc_loss: -0.8360815048217773 | gen_loss: -0.043960098177194595
# Iteration: 477 | disc_loss: -0.8348492980003357 | gen_loss: -0.053156301379203796
# Iteration: 478 | disc_loss: -0.834393322467804 | gen_loss: -0.046311959624290466
# Iteration: 479 | disc_loss: -0.8443201780319214 | gen_loss: -0.04893101751804352
# Iteration: 480 | disc_loss: -0.843895435333252 | gen_loss: -0.053082555532455444
# Iteration: 481 | disc_loss: -0.8364314436912537 | gen_loss: -0.042420174926519394
# Iteration: 482 | disc_loss: -0.8249543905258179 | gen_loss: -0.052085962146520615
# Iteration: 483 | disc_loss: -0.8412916660308838 | gen_loss: -0.05046942085027695
# Iteration: 484 | disc_loss: -0.8403564691543579 | gen_loss: -0.04352143034338951
# Iteration: 485 | disc_loss: -0.8318297863006592 | gen_loss: -0.056127700954675674
# Iteration: 486 | disc_loss: -0.8232024312019348 | gen_loss: -0.04581751301884651
# Iteration: 487 | disc_loss: -0.8395034074783325 | gen_loss: -0.049550861120224
# Iteration: 488 | disc_loss: -0.8400564789772034 | gen_loss: -0.05405748263001442
# Iteration: 489 | disc_loss: -0.8408359289169312 | gen_loss: -0.04553971439599991
# 100%|██████████| 500/500 [00:06<00:00, 80.64it/s]
# Iteration: 490 | disc_loss: -0.8330249190330505 | gen_loss: -0.053889792412519455
# Iteration: 491 | disc_loss: -0.8273617625236511 | gen_loss: -0.043747905641794205
# Iteration: 492 | disc_loss: -0.8332822918891907 | gen_loss: -0.05018630996346474
# Iteration: 493 | disc_loss: -0.8397977352142334 | gen_loss: -0.04900623857975006
# Iteration: 494 | disc_loss: -0.8412559032440186 | gen_loss: -0.04832112044095993
# Iteration: 495 | disc_loss: -0.8399330377578735 | gen_loss: -0.053264204412698746
# Iteration: 496 | disc_loss: -0.8434844613075256 | gen_loss: -0.04552130773663521
# Iteration: 497 | disc_loss: -0.8244245052337646 | gen_loss: -0.05663551017642021
# Iteration: 498 | disc_loss: -0.8139216303825378 | gen_loss: -0.045913755893707275
# Iteration: 499 | disc_loss: -0.8356310129165649 | gen_loss: -0.04905179142951965

# %%
#Sampling the data
failure_synth = synthesizer.sample(healthy.shape[0] - failure.shape[0])
# Out:
# Synthetic data generation: 100%|██████████| 337/337 [00:00<00:00, 382.62it/s]

# %%
failure_synth.columns = data_cols
failure_synth['label'] = [1 for x in range(failure_synth.shape[0])]

# %%
# Creating Synthethic Data
synthetic_failure = pd.concat([failure, failure_synth[:-48]])
synthetic_data = pd.concat([healthy, synthetic_failure]).reset_index(drop=True)

# %%
# Display new class count - with synthethic data
class_distribution(synthetic_data, 'GAN Synthetic Data')

# %%
# Splitting intro train and test data
Xsynth_train, Xsynth_test, ysynth_train, ysynth_test = train_test_split(synthetic_data.drop(columns=['label']), 
                                                                        synthetic_data['label'], 
                                                                        test_size=0.2, 
                                                                        random_state=123)

# %% [markdown]
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Modeling

# %%
# Instantiating logistic regression, decision tree, random forest, and xgboost models
logreg = LogisticRegression(random_state=123) # Logistic Regression 
dtc = DecisionTreeClassifier(random_state=123) # Decision Tree
rfc = RandomForestClassifier(random_state=123) # Random Forest
xgb = XGBClassifier(objective='binary:logistic', n_estimators=100, eval_metric='logloss') # XGBoost

# %%
# Neural Network"
def neural_network():
    neural_network = Sequential([
        Dense(14, input_dim=13, activation='relu', name="Input_Layer"),
        Dense(8, activation='relu', name="Hidden_Layer_1"),
        Dense(1, activation='softmax', name="Output_Layer"),
    ], name="neural_network")
    
    neural_network.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return neural_network
    
print(neural_network().summary())
# Out:
# Model: "neural_network"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input_Layer (Dense)          (None, 14)                196
# _________________________________________________________________
# Hidden_Layer_1 (Dense)       (None, 8)                 120
# _________________________________________________________________
# Output_Layer (Dense)         (None, 1)                 9
# =================================================================
# Total params: 325
# Trainable params: 325
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Part I - Imbalance vs Balance

# %% [markdown]
# #### Data Imbalance

# %%
# Logistic Regression
logregfit = logreg.fit(X_train, y_train)
logpred = logregfit.predict(X_test)

# Scores
accuracy_logreg = accuracy_score(y_test, logpred)
f1_logreg = f1_score(y_test, logpred)
recall_logreg = recall_score(y_test, logpred)
prec_logreg = precision_score(y_test, logpred)

# %%
# Decision Tree
dtcfit = dtc.fit(X_train, y_train)
dtcpred = dtcfit.predict(X_test)

# Score
accuracy_dtc = accuracy_score(y_test, dtcpred)
f1_dtc = f1_score(y_test, dtcpred)
recall_dtc = recall_score(y_test, dtcpred)
prec_dtc = precision_score(y_test, dtcpred)

# %%
# Random Forest
rfcfit = rfc.fit(X_train, y_train)
rfcpred = rfcfit.predict(X_test)

# Score
accuracy_rfc = accuracy_score(y_test, rfcpred)
f1_rfc = f1_score(y_test, rfcpred)
recall_rfc = recall_score(y_test, rfcpred)
prec_rfc = precision_score(y_test, rfcpred)

# %%
# XGBoost
xgbfit = xgb.fit(X_train, y_train)
xgbpred = xgbfit.predict(X_test)

# Score
accuracy_xgb = accuracy_score(y_test, xgbpred)
f1_xgb = f1_score(y_test, xgbpred)
recall_xgb = recall_score(y_test, xgbpred)
prec_xgb = precision_score(y_test, xgbpred)

# %%
# Neural Network
nn = neural_network()
nn.fit(X_train, y_train, epochs = 30)
nn_pred = nn.predict(X_test)

# Score
accuracy_nn = accuracy_score(y_test, nn_pred)
f1_nn = f1_score(y_test, nn_pred)
recall_nn = recall_score(y_test, nn_pred)
prec_nn = precision_score(y_test, nn_pred)
# Out:
# Epoch 1/30
# 618/618 [==============================] - 2s 2ms/step - loss: 0.5085 - accuracy: 0.0682
# Epoch 2/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0761 - accuracy: 0.0612
# Epoch 3/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0593 - accuracy: 0.0653
# Epoch 4/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0572 - accuracy: 0.0652
# Epoch 5/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0497 - accuracy: 0.0634
# Epoch 6/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0477 - accuracy: 0.0632
# Epoch 7/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0450 - accuracy: 0.0630
# Epoch 8/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0488 - accuracy: 0.0658
# Epoch 9/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0454 - accuracy: 0.0649
# Epoch 10/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0450 - accuracy: 0.0640
# Epoch 11/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0455 - accuracy: 0.0659
# Epoch 12/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0417 - accuracy: 0.0643: 0s - loss: 0.0417 - accuracy: 0.06
# Epoch 13/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0419 - accuracy: 0.0628
# Epoch 14/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0415 - accuracy: 0.0621
# Epoch 15/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0452 - accuracy: 0.0683
# Epoch 16/30
# 618/618 [==============================] - 1s 1ms/step - loss: 0.0437 - accuracy: 0.0677
# Epoch 17/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0417 - accuracy: 0.0646
# Epoch 18/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0444 - accuracy: 0.0653
# Epoch 19/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0422 - accuracy: 0.0636
# Epoch 20/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0414 - accuracy: 0.0691
# Epoch 21/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0414 - accuracy: 0.0656
# Epoch 22/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0407 - accuracy: 0.0642
# Epoch 23/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0397 - accuracy: 0.0654
# Epoch 24/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0373 - accuracy: 0.0647: 0s - l
# Epoch 25/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0395 - accuracy: 0.0658: 0s - loss: 0.0394 - accuracy: 0.06
# Epoch 26/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0418 - accuracy: 0.0648
# Epoch 27/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0387 - accuracy: 0.0644
# Epoch 28/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0401 - accuracy: 0.0620
# Epoch 29/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0430 - accuracy: 0.0672
# Epoch 30/30
# 618/618 [==============================] - 1s 2ms/step - loss: 0.0416 - accuracy: 0.0651

# %% [markdown]
# #### Dealing with Data Imbalance

# %% [markdown]
# - Upsampling:

# %%
# Logistic Regression
logregbal = logreg.fit(Xbal_train, ybal_train)
logbalpred = logregbal.predict(Xbal_test)

# Scores
accuracy_logregbal = accuracy_score(ybal_test, logbalpred)
f1_logregbal = f1_score(ybal_test, logbalpred)
recall_logregbal = recall_score(ybal_test, logbalpred)
prec_logregbal = precision_score(ybal_test, logbalpred)

# %%
# Decision Tree 
dtcbal = dtc.fit(Xbal_train, ybal_train)
dtcbalpred = dtcbal.predict(Xbal_test)

# Scores
accuracy_dtcbal = accuracy_score(ybal_test, dtcbalpred)
f1_dtcbal = f1_score(ybal_test, dtcbalpred)
recall_dtcbal = recall_score(ybal_test, dtcbalpred)
prec_dtcbal = precision_score(ybal_test, dtcbalpred)

# %%
# Random Forest
rfcbal = rfc.fit(Xbal_train, ybal_train)
rfcbalpred = rfcbal.predict(Xbal_test)

# Scores
accuracy_rfcbal = accuracy_score(ybal_test, rfcbalpred)
f1_rfcbal = f1_score(ybal_test, rfcbalpred)
recall_rfcbal = recall_score(ybal_test, rfcbalpred)
prec_rfcbal = precision_score(ybal_test, rfcbalpred)

# %%
# XGBoost
xgbbal = xgb.fit(Xbal_train, ybal_train)
xgbbalpred = xgbbal.predict(Xbal_test)

# Scores
accuracy_xgbbal = accuracy_score(ybal_test, xgbbalpred)
f1_xgbbal = f1_score(ybal_test, xgbbalpred)
recall_xgbbal = recall_score(ybal_test, xgbbalpred)
prec_xgbbal = precision_score(ybal_test, xgbbalpred)

# %%
# Neural Network
nnbal = neural_network()
nnbal.fit(Xbal_train, ybal_train, epochs = 30)
nnbal_pred = nnbal.predict(Xbal_test)

# Score
accuracy_nnbal = accuracy_score(ybal_test, nnbal_pred)
f1_nnbal = f1_score(ybal_test, nnbal_pred)
recall_nnbal = recall_score(ybal_test, nnbal_pred)
prec_nnbal = precision_score(ybal_test, nnbal_pred)
# Out:
# Epoch 1/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.3519 - accuracy: 0.4966
# Epoch 2/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0866 - accuracy: 0.4984
# Epoch 3/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0797 - accuracy: 0.4954
# Epoch 4/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0770 - accuracy: 0.4975
# Epoch 5/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0781 - accuracy: 0.4956
# Epoch 6/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0755 - accuracy: 0.4972
# Epoch 7/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0778 - accuracy: 0.4980
# Epoch 8/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0732 - accuracy: 0.4952
# Epoch 9/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0708 - accuracy: 0.4947: 0s - los
# Epoch 10/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0737 - accuracy: 0.5000
# Epoch 11/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0731 - accuracy: 0.4950
# Epoch 12/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0696 - accuracy: 0.4972: 0s - loss: 0.0696 - accuracy: 0.49
# Epoch 13/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0725 - accuracy: 0.4969
# Epoch 14/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0698 - accuracy: 0.4954
# Epoch 15/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0707 - accuracy: 0.4934
# Epoch 16/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0689 - accuracy: 0.4971
# Epoch 17/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0668 - accuracy: 0.4992
# Epoch 18/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0690 - accuracy: 0.4967
# Epoch 19/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0675 - accuracy: 0.4956
# Epoch 20/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0648 - accuracy: 0.4946:
# Epoch 21/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0670 - accuracy: 0.4955: 1s - loss: 0 - ETA: 0s - loss:
# Epoch 22/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0674 - accuracy: 0.5007
# Epoch 23/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0649 - accuracy: 0.4963
# Epoch 24/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0651 - accuracy: 0.5012
# Epoch 25/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0676 - accuracy: 0.4988
# Epoch 26/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0667 - accuracy: 0.4998
# Epoch 27/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0643 - accuracy: 0.4971
# Epoch 28/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0639 - accuracy: 0.4988
# Epoch 29/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0649 - accuracy: 0.4979
# Epoch 30/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0634 - accuracy: 0.4941

# %% [markdown]
# - Synthethic Data:

# %%
# Logistic Regression
logregsynth = logreg.fit(Xsynth_train, ysynth_train)
logsynthpred = logregsynth.predict(Xsynth_test)

# Scores
accuracy_logregsynth = accuracy_score(ysynth_test, logsynthpred)
f1_logregsynth = f1_score(ysynth_test, logsynthpred)
recall_logregsynth = recall_score(ysynth_test, logsynthpred)
prec_logregsynth = precision_score(ysynth_test, logsynthpred)

# %%
# Decision Tree
dtcsynth = dtc.fit(Xsynth_train, ysynth_train)
dtcsynthpred = dtcsynth.predict(Xsynth_test)

# Scores
accuracy_dtcsynth = accuracy_score(ysynth_test, dtcsynthpred)
f1_dtcsynth = f1_score(ysynth_test, dtcsynthpred)
recall_dtcsynth = recall_score(ysynth_test, dtcsynthpred)
prec_dtcsynth = precision_score(ysynth_test, dtcsynthpred)

# %%
# Random Forest
rfcsynth = rfc.fit(Xsynth_train, ysynth_train)
rfcsynthpred = rfcsynth.predict(Xsynth_test)

# Scores
accuracy_rfcsynth = accuracy_score(ysynth_test, rfcsynthpred)
f1_rfcsynth = f1_score(ysynth_test, rfcsynthpred)
recall_rfcsynth = recall_score(ysynth_test, rfcsynthpred)
prec_rfcsynth = precision_score(ysynth_test, rfcsynthpred)

# %%
# XGBoost
xgbsynth = xgb.fit(Xsynth_train, ysynth_train)
xgbsynthpred = xgbsynth.predict(Xsynth_test)

# Scores
accuracy_xgbsynth = accuracy_score(ysynth_test, xgbsynthpred)
f1_xgbsynth = f1_score(ysynth_test, xgbsynthpred)
recall_xgbsynth = recall_score(ysynth_test, xgbsynthpred)
prec_xgbsynth = precision_score(ysynth_test, xgbsynthpred)

# %%
# Neural Network
nnsynth = neural_network()
nnsynth.fit(Xsynth_train, ysynth_train, epochs = 30)
nnsynth_pred = nnsynth.predict(Xsynth_test)

# Score
accuracy_nnsynth = accuracy_score(ysynth_test, nnsynth_pred)
f1_nnsynth = f1_score(ysynth_test, nnsynth_pred)
recall_nnsynth = recall_score(ysynth_test, nnsynth_pred)
prec_nnsynth = precision_score(ysynth_test, nnsynth_pred)
# Out:
# Epoch 1/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.3019 - accuracy: 0.4958
# Epoch 2/30
# 1156/1156 [==============================] - 1s 1ms/step - loss: 0.0454 - accuracy: 0.4968
# Epoch 3/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0396 - accuracy: 0.4954
# Epoch 4/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0384 - accuracy: 0.4982: 0s - loss: 0.0384 - accuracy:
# Epoch 5/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0379 - accuracy: 0.4966
# Epoch 6/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0362 - accuracy: 0.4942
# Epoch 7/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0354 - accuracy: 0.4962
# Epoch 8/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0329 - accuracy: 0.4921
# Epoch 9/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0345 - accuracy: 0.5004
# Epoch 10/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0339 - accuracy: 0.4995
# Epoch 11/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0339 - accuracy: 0.4967
# Epoch 12/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0321 - accuracy: 0.4961:
# Epoch 13/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0323 - accuracy: 0.4911
# Epoch 14/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0336 - accuracy: 0.4976
# Epoch 15/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0318 - accuracy: 0.4933
# Epoch 16/30
# 1156/1156 [==============================] - 3s 2ms/step - loss: 0.0346 - accuracy: 0.4955
# Epoch 17/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0306 - accuracy: 0.4950
# Epoch 18/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0316 - accuracy: 0.4975
# Epoch 19/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0327 - accuracy: 0.4941
# Epoch 20/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0302 - accuracy: 0.4994: 0s - loss: 0.0301 - accuracy: 0.
# Epoch 21/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0297 - accuracy: 0.4982
# Epoch 22/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0315 - accuracy: 0.4953
# Epoch 23/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0330 - accuracy: 0.4960: 0s - loss: 0.0334 - accu
# Epoch 24/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0322 - accuracy: 0.4986
# Epoch 25/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0304 - accuracy: 0.4923
# Epoch 26/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0309 - accuracy: 0.4988
# Epoch 27/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0333 - accuracy: 0.4954
# Epoch 28/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0310 - accuracy: 0.4972
# Epoch 29/30
# 1156/1156 [==============================] - 2s 2ms/step - loss: 0.0311 - accuracy: 0.4958
# Epoch 30/30
# 1156/1156 [==============================] - 2s 1ms/step - loss: 0.0287 - accuracy: 0.4985

# %% [markdown]
# ### Finding Best Model

# %%
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'XGBoost', 'Neural Network',
          'Logistic Regression with Upsampled', 'Decision Tree with Upsampled', 
          'Random Forest with Upsampled', 'XGBoost with Upsampled', 'Neural Network with Upsampled',
          'Logistic Regression with Synthetic Data', 'Decision Tree with Synthetic Data', 
          'Random Forest with Synthetic Data', 'XGBoost with Synthetic Data', 'Neural Network with Synthetic Data']
accuracies = np.array([accuracy_logreg, accuracy_dtc, accuracy_rfc, accuracy_xgb, accuracy_nn,
                       accuracy_logregbal, accuracy_dtcbal, accuracy_rfcbal, accuracy_xgbbal, accuracy_nnbal,
                       accuracy_logregsynth, accuracy_dtcsynth, accuracy_rfcsynth, accuracy_xgbsynth, accuracy_nnsynth
                      ])
recalls = np.array([recall_logreg, recall_dtc, recall_rfc, recall_xgb, recall_nn,
                    recall_logregbal, recall_dtcbal, recall_rfcbal, recall_xgbbal, recall_nnbal,
                    recall_logregsynth, recall_dtcsynth, recall_rfcsynth, recall_xgbsynth, recall_nnsynth
                   ]) 
precisions = np.array([prec_logreg, prec_dtc, prec_rfc, prec_xgb, prec_nn,
                       prec_logregbal, prec_dtcbal, prec_rfcbal, prec_xgbbal, prec_nnbal,
                       prec_logregsynth, prec_dtcsynth, prec_rfcsynth, prec_xgbsynth, prec_nnsynth
                      ]) 
f1_score = np.array([f1_logreg, f1_dtc, f1_rfc, f1_xgb, f1_nn,
                     f1_logregbal, f1_dtcbal, f1_rfcbal, f1_xgbbal, f1_nnbal,
                     f1_logregsynth, f1_dtcsynth, f1_rfcsynth, f1_xgbsynth, f1_nnsynth
                      ])

# %%
# Creating DataFrame with Scores
scores = {'Accuracy': accuracies,
          'Recall': recalls,
          'Precision' : precisions,
          'F1_Score': f1_score
         }

scores_df = pd.DataFrame(scores, 
                         columns = ['Accuracy', 'Recall', 'Precision', 'F1_Score'], 
                         index = models)

# %%
inspect = ['Decision Tree with Upsampled', 
           'Random Forest with Upsampled', 
           'XGBoost with Upsampled'
          ]

scores_df.style.apply(lambda x: ['background: lightyellow' 
                                 if x.name in inspect 
                                 else ''
                                 for i in x], axis=1)
# Out:
# <style  type="text/css" >
# #T_e2bbb_row6_col0,#T_e2bbb_row6_col1,#T_e2bbb_row6_col2,#T_e2bbb_row6_col3,#T_e2bbb_row7_col0,#T_e2bbb_row7_col1,#T_e2bbb_row7_col2,#T_e2bbb_row7_col3,#T_e2bbb_row8_col0,#T_e2bbb_row8_col1,#T_e2bbb_row8_col2,#T_e2bbb_row8_col3{
#             background:  lightyellow;
#         }</style><table id="T_e2bbb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >Recall</th>        <th class="col_heading level0 col2" >Precision</th>        <th class="col_heading level0 col3" >F1_Score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2bbb_level0_row0" class="row_heading level0 row0" >Logistic Regression</th>
#                         <td id="T_e2bbb_row0_col0" class="data row0 col0" >0.983010</td>
#                         <td id="T_e2bbb_row0_col1" class="data row0 col1" >0.854430</td>
#                         <td id="T_e2bbb_row0_col2" class="data row0 col2" >0.876623</td>
#                         <td id="T_e2bbb_row0_col3" class="data row0 col3" >0.865385</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row1" class="row_heading level0 row1" >Decision Tree</th>
#                         <td id="T_e2bbb_row1_col0" class="data row1 col0" >0.972492</td>
#                         <td id="T_e2bbb_row1_col1" class="data row1 col1" >0.775316</td>
#                         <td id="T_e2bbb_row1_col2" class="data row1 col2" >0.790323</td>
#                         <td id="T_e2bbb_row1_col3" class="data row1 col3" >0.782748</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#                         <td id="T_e2bbb_row2_col0" class="data row2 col0" >0.982605</td>
#                         <td id="T_e2bbb_row2_col1" class="data row2 col1" >0.835443</td>
#                         <td id="T_e2bbb_row2_col2" class="data row2 col2" >0.885906</td>
#                         <td id="T_e2bbb_row2_col3" class="data row2 col3" >0.859935</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row3" class="row_heading level0 row3" >XGBoost</th>
#                         <td id="T_e2bbb_row3_col0" class="data row3 col0" >0.981998</td>
#                         <td id="T_e2bbb_row3_col1" class="data row3 col1" >0.825949</td>
#                         <td id="T_e2bbb_row3_col2" class="data row3 col2" >0.884746</td>
#                         <td id="T_e2bbb_row3_col3" class="data row3 col3" >0.854337</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row4" class="row_heading level0 row4" >Neural Network</th>
#                         <td id="T_e2bbb_row4_col0" class="data row4 col0" >0.063916</td>
#                         <td id="T_e2bbb_row4_col1" class="data row4 col1" >1.000000</td>
#                         <td id="T_e2bbb_row4_col2" class="data row4 col2" >0.063916</td>
#                         <td id="T_e2bbb_row4_col3" class="data row4 col3" >0.120152</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row5" class="row_heading level0 row5" >Logistic Regression with Upsampled</th>
#                         <td id="T_e2bbb_row5_col0" class="data row5 col0" >0.970588</td>
#                         <td id="T_e2bbb_row5_col1" class="data row5 col1" >0.980492</td>
#                         <td id="T_e2bbb_row5_col2" class="data row5 col2" >0.962531</td>
#                         <td id="T_e2bbb_row5_col3" class="data row5 col3" >0.971429</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row6" class="row_heading level0 row6" >Decision Tree with Upsampled</th>
#                         <td id="T_e2bbb_row6_col0" class="data row6 col0" >0.991998</td>
#                         <td id="T_e2bbb_row6_col1" class="data row6 col1" >1.000000</td>
#                         <td id="T_e2bbb_row6_col2" class="data row6 col2" >0.984551</td>
#                         <td id="T_e2bbb_row6_col3" class="data row6 col3" >0.992215</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row7" class="row_heading level0 row7" >Random Forest with Upsampled</th>
#                         <td id="T_e2bbb_row7_col0" class="data row7 col0" >0.993188</td>
#                         <td id="T_e2bbb_row7_col1" class="data row7 col1" >1.000000</td>
#                         <td id="T_e2bbb_row7_col2" class="data row7 col2" >0.986817</td>
#                         <td id="T_e2bbb_row7_col3" class="data row7 col3" >0.993365</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row8" class="row_heading level0 row8" >XGBoost with Upsampled</th>
#                         <td id="T_e2bbb_row8_col0" class="data row8 col0" >0.990917</td>
#                         <td id="T_e2bbb_row8_col1" class="data row8 col1" >1.000000</td>
#                         <td id="T_e2bbb_row8_col2" class="data row8 col2" >0.982500</td>
#                         <td id="T_e2bbb_row8_col3" class="data row8 col3" >0.991173</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row9" class="row_heading level0 row9" >Neural Network with Upsampled</th>
#                         <td id="T_e2bbb_row9_col0" class="data row9 col0" >0.509948</td>
#                         <td id="T_e2bbb_row9_col1" class="data row9 col1" >1.000000</td>
#                         <td id="T_e2bbb_row9_col2" class="data row9 col2" >0.509948</td>
#                         <td id="T_e2bbb_row9_col3" class="data row9 col3" >0.675451</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row10" class="row_heading level0 row10" >Logistic Regression with Synthetic Data</th>
#                         <td id="T_e2bbb_row10_col0" class="data row10 col0" >0.902249</td>
#                         <td id="T_e2bbb_row10_col1" class="data row10 col1" >0.995123</td>
#                         <td id="T_e2bbb_row10_col2" class="data row10 col2" >0.841945</td>
#                         <td id="T_e2bbb_row10_col3" class="data row10 col3" >0.912148</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row11" class="row_heading level0 row11" >Decision Tree with Synthetic Data</th>
#                         <td id="T_e2bbb_row11_col0" class="data row11 col0" >0.985835</td>
#                         <td id="T_e2bbb_row11_col1" class="data row11 col1" >0.984521</td>
#                         <td id="T_e2bbb_row11_col2" class="data row11 col2" >0.987662</td>
#                         <td id="T_e2bbb_row11_col3" class="data row11 col3" >0.986089</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row12" class="row_heading level0 row12" >Random Forest with Synthetic Data</th>
#                         <td id="T_e2bbb_row12_col0" class="data row12 col0" >0.988646</td>
#                         <td id="T_e2bbb_row12_col1" class="data row12 col1" >0.986217</td>
#                         <td id="T_e2bbb_row12_col2" class="data row12 col2" >0.991473</td>
#                         <td id="T_e2bbb_row12_col3" class="data row12 col3" >0.988838</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row13" class="row_heading level0 row13" >XGBoost with Synthetic Data</th>
#                         <td id="T_e2bbb_row13_col0" class="data row13 col0" >0.989619</td>
#                         <td id="T_e2bbb_row13_col1" class="data row13 col1" >0.986641</td>
#                         <td id="T_e2bbb_row13_col2" class="data row13 col2" >0.992958</td>
#                         <td id="T_e2bbb_row13_col3" class="data row13 col3" >0.989789</td>
#             </tr>
#             <tr>
#                         <th id="T_e2bbb_level0_row14" class="row_heading level0 row14" >Neural Network with Synthetic Data</th>
#                         <td id="T_e2bbb_row14_col0" class="data row1

# %% [markdown]
# - Inspecting False Negatives and False Positives:

# %%
# Extracting Number of FNs and FPS
_, fp_dtcbal, fn_dtcbal, _ = confusion_matrix(ybal_test, dtcbalpred).ravel()
_, fp_rfcbal, fn_rfcbal, _ = confusion_matrix(ybal_test, rfcbalpred).ravel()
_, fp_xgbbal, fn_xgbbal, _ = confusion_matrix(ybal_test, xgbbalpred).ravel()

# %%
models_falses = ['Decision Tree with Upsampled Data', 
                 'Random Forest with Upsampled Data', 
                 'XGBoost with Upsampled Data'
                ]
fpositives = np.array([fp_dtcbal, fp_rfcbal, fp_xgbbal])
fnegatives = np.array([fn_dtcbal, fn_rfcbal, fn_xgbbal])

# %%
# Creating DataFrame with False Positives and False Negatives
falses = {'False Positives': fpositives,
          'False Negatives': fnegatives,
         }

falses_df = pd.DataFrame(falses, 
                         columns = ['False Positives', 'False Negatives'], 
                         index = models_falses)

# %%
best = ['Random Forest with Upsampled Data']

falses_df.style.apply(lambda x: ['background: lightgreen' 
                                 if x.name in best 
                                 else ''
                                 for i in x], axis=1)
# Out:
# <style  type="text/css" >
# #T_852a6_row1_col0,#T_852a6_row1_col1{
#             background:  lightgreen;
#         }</style><table id="T_852a6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >False Positives</th>        <th class="col_heading level0 col1" >False Negatives</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_852a6_level0_row0" class="row_heading level0 row0" >Decision Tree with Upsampled Data</th>
#                         <td id="T_852a6_row0_col0" class="data row0 col0" >74</td>
#                         <td id="T_852a6_row0_col1" class="data row0 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_852a6_level0_row1" class="row_heading level0 row1" >Random Forest with Upsampled Data</th>
#                         <td id="T_852a6_row1_col0" class="data row1 col0" >63</td>
#                         <td id="T_852a6_row1_col1" class="data row1 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_852a6_level0_row2" class="row_heading level0 row2" >XGBoost with Upsampled Data</th>
#                         <td id="T_852a6_row2_col0" class="data row2 col0" >84</td>
#                         <td id="T_852a6_row2_col1" class="data row2 col1" >0</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Part II - Feature Importance

# %%
dtypes = [('Feature', np.unicode_, 16), ('Importance', float)]

# %% [markdown]
# - Decision Tree with Upsampled Data:

# %%
fig = plt.figure(figsize=(15,6))
_ = tree.plot_tree(dtcbal,
                   filled=True,
                   feature_names=data_cols,
                   max_depth=2,
                   rounded=True)

# %%
fig = plt.figure(figsize=(10,6))
idx_sort = dtcbal.feature_importances_.argsort()
plt.barh(data_upsampled.columns[idx_sort][-6:], dtcbal.feature_importances_[idx_sort][-6:])
plt.title('Decision Tree with Upsampled Data Feature Importance')
plt.xlabel("Importance")
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# - Random Forest with Upsampled Data:

# %%
fig = plt.figure(figsize=(10,6))
idx_sort = rfcbal.feature_importances_.argsort()
plt.barh(data_upsampled.columns[idx_sort][-6:], rfcbal.feature_importances_[idx_sort][-6:], color='orange')
plt.title('Random Forest with Upsampled Data Feature Importance')
plt.xlabel("Importance")
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# - XGBoost with Upsampled Data:

# %%
fig = plt.figure(figsize=(10,6))
idx_sort = xgbbal.feature_importances_.argsort()
plt.barh(data_upsampled.columns[idx_sort][-6:], xgbbal.feature_importances_[idx_sort][-6:], color='green')
plt.title('XGBoost with Upsampled Data Feature Importance')
plt.xlabel("Importance")
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# ### Part III - Improving Best Model

# %% [markdown]
# - Stacking Models:

# %%
# Defining base models
base_models = [('dtc', DecisionTreeClassifier(random_state=123)),
               ('rfc', RandomForestClassifier(random_state=123)),
               ('xgb', XGBClassifier(objective='binary:logistic', n_estimators=100, eval_metric='logloss'))
              ]
    
# define the stacking ensemble
stack_model = StackingClassifier(estimators=base_models, final_estimator=LogisticRegression(random_state=123), cv=5)

# %%
# Fitting and Making Predictions
stack_fit = stack_model.fit(Xbal_train, ybal_train)
stack_pred = stack_fit.predict(Xbal_test)

# %%
# Scores
accuracy_stack = accuracy_score(ybal_test, stack_pred)
f1_stack = f1_score(ybal_test.to_numpy(), stack_pred)
recall_stack = recall_score(ybal_test, stack_pred)
prec_stack = precision_score(ybal_test, stack_pred)
_, fp_stack, fn_stack, _ = confusion_matrix(ybal_test, stack_pred).ravel()

# %%
pd.DataFrame([[accuracy_stack, f1_stack, recall_stack, prec_stack, fp_stack, fn_stack]], 
             columns = ['Accuracy', 'F1_Score', 'Recall', 'Precision', 'False_Positives', 'False_Negatives'],
             index = ['Stacking Model - Logistic Estimator'])
# Out:
#                                      Accuracy  F1_Score  Recall  Precision  \
# Stacking Model - Logistic Estimator   0.99827  0.998307     1.0   0.996619
#
#                                      False_Positives  False_Negatives
# Stacking Model - Logistic Estimator               16                0

# %% [markdown]
# - Grid Search:

# %%
# Creating Param Dictionary
params = {"final_estimator": [LogisticRegression(random_state=123), 
                              DecisionTreeClassifier(random_state=123), 
                              RandomForestClassifier(random_state=123),
                              XGBClassifier(objective='binary:logistic', n_estimators=100, eval_metric = 'logloss')
                             ]
         }

# %%
# Instantiating Grid Search
stack_grid = GridSearchCV(estimator = stack_model, 
                          param_grid = params, 
                          cv = 5,
                          scoring = "f1",
                          verbose = 3,
                          n_jobs = -1)

# %%
# Fitting and predicting with best model
best_fit = stack_grid.fit(Xbal_train, ybal_train)
best_pred = best_fit.predict(Xbal_test)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  5.9min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  5.9min finished

# %%
# Scores Best Model
accuracy_best = accuracy_score(ybal_test, best_pred)
f1_best = f1_score(ybal_test, stack_pred)
recall_best = recall_score(ybal_test, best_pred)
prec_best = precision_score(ybal_test, best_pred)
_, fp_best, fn_best, _ = confusion_matrix(ybal_test, best_pred).ravel()

# %% [markdown]
# # Results

# %% [markdown]
# - Best Model:

# %%
lista_models = ['Decision Tree with Upsampled Data', 'Random Forest with Upsampled Data', 'XGBoost with Upsampled Data',
                'Stacking Model - Logistic Regression Estimator', 'Stacking Model - XGBoost Estimator']
dtup = [accuracy_dtcbal, f1_dtcbal, recall_dtcbal, prec_dtcbal, fp_dtcbal, fn_dtcbal]
rfup = [accuracy_rfcbal, f1_rfcbal, recall_rfcbal, prec_rfcbal, fp_rfcbal, fn_rfcbal]
xgbup = [accuracy_xgbbal, f1_xgbbal, recall_xgbbal, prec_xgbbal, fp_xgbbal, fn_xgbbal]
logstack = [accuracy_stack, f1_stack, recall_stack, prec_stack, fp_stack, fn_stack]
xgbstack = [accuracy_best, f1_best, recall_best, prec_best, fp_best, fn_best]

# %%
best_df = pd.DataFrame([dtup, rfup, xgbup, logstack, xgbstack], 
                       columns = ['Accuracy', 'F1_Score', 'Recall', 'Precision', 'False_Positives', 'False_Negatives'],
                       index = lista_models)
best_df.style.apply(lambda x: ['background: lightgreen' 
                                 if x.name in ['Stacking Model - XGBoost Estimator'] 
                                 else ''
                                 for i in x], axis=1)
# Out:
# <style  type="text/css" >
# #T_88dd1_row4_col0,#T_88dd1_row4_col1,#T_88dd1_row4_col2,#T_88dd1_row4_col3,#T_88dd1_row4_col4,#T_88dd1_row4_col5{
#             background:  lightgreen;
#         }</style><table id="T_88dd1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >F1_Score</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Precision</th>        <th class="col_heading level0 col4" >False_Positives</th>        <th class="col_heading level0 col5" >False_Negatives</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88dd1_level0_row0" class="row_heading level0 row0" >Decision Tree with Upsampled Data</th>
#                         <td id="T_88dd1_row0_col0" class="data row0 col0" >0.991998</td>
#                         <td id="T_88dd1_row0_col1" class="data row0 col1" >0.992215</td>
#                         <td id="T_88dd1_row0_col2" class="data row0 col2" >1.000000</td>
#                         <td id="T_88dd1_row0_col3" class="data row0 col3" >0.984551</td>
#                         <td id="T_88dd1_row0_col4" class="data row0 col4" >74</td>
#                         <td id="T_88dd1_row0_col5" class="data row0 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_88dd1_level0_row1" class="row_heading level0 row1" >Random Forest with Upsampled Data</th>
#                         <td id="T_88dd1_row1_col0" class="data row1 col0" >0.993188</td>
#                         <td id="T_88dd1_row1_col1" class="data row1 col1" >0.993365</td>
#                         <td id="T_88dd1_row1_col2" class="data row1 col2" >1.000000</td>
#                         <td id="T_88dd1_row1_col3" class="data row1 col3" >0.986817</td>
#                         <td id="T_88dd1_row1_col4" class="data row1 col4" >63</td>
#                         <td id="T_88dd1_row1_col5" class="data row1 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_88dd1_level0_row2" class="row_heading level0 row2" >XGBoost with Upsampled Data</th>
#                         <td id="T_88dd1_row2_col0" class="data row2 col0" >0.990917</td>
#                         <td id="T_88dd1_row2_col1" class="data row2 col1" >0.991173</td>
#                         <td id="T_88dd1_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_88dd1_row2_col3" class="data row2 col3" >0.982500</td>
#                         <td id="T_88dd1_row2_col4" class="data row2 col4" >84</td>
#                         <td id="T_88dd1_row2_col5" class="data row2 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_88dd1_level0_row3" class="row_heading level0 row3" >Stacking Model - Logistic Regression Estimator</th>
#                         <td id="T_88dd1_row3_col0" class="data row3 col0" >0.998270</td>
#                         <td id="T_88dd1_row3_col1" class="data row3 col1" >0.998307</td>
#                         <td id="T_88dd1_row3_col2" class="data row3 col2" >1.000000</td>
#                         <td id="T_88dd1_row3_col3" class="data row3 col3" >0.996619</td>
#                         <td id="T_88dd1_row3_col4" class="data row3 col4" >16</td>
#                         <td id="T_88dd1_row3_col5" class="data row3 col5" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_88dd1_level0_row4" class="row_heading level0 row4" >Stacking Model - XGBoost Estimator</th>
#                         <td id="T_88dd1_row4_col0" class="data row4 col0" >0.999892</td>
#                         <td id="T_88dd1_row4_col1" class="data row4 col1" >0.998307</td>
#                         <td id="T_88dd1_row4_col2" class="data row4 col2" >1.000000</td>
#                         <td id="T_88dd1_row4_col3" class="data row4 col3" >0.999788</td>
#                         <td id="T_88dd1_row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_88dd1_row4_col5" class="data row4 col5" >0</td>
#             </tr>
#     </tbody></table>
